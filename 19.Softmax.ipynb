# %% [markdown]
# # Softmax

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# # Using Numpy

# %%
# "Manually" in numpy

# The List of number
z = [1,2,3]

#compute the softmax result
num = np.exp(z)
den = np.sum( np.exp(z))
sigma = num / den

print (sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
#Repeat with some random integers
z = np.random.randint(-5, high=15, size=25)
print(z)

#Compute the softmax result
num = np.exp(z)
den = np.sum(num)
sigma = num/den

#Compare
plt.plot(z, sigma, 'ko')
plt.xlabel("Original Number (z)")
plt.ylabel("Softmaxified $\sigma$")
# plt.yscale('log')
plt.title('$\sum\sigma$ = %g' %np.sum(sigma))
plt.show()
# Out:
# [-4  0 -1 -1 10  4  2 -5  0  4 -3 -3  1  1  1  8 12  8 -1  3  8  4  2  2
#   7]

# %% [markdown]
# # Using Pytorch

# %%
#Slightly more involved using torch.nn

#Create an instance of the softmax activation class
softfun = nn.Softmax(dim=0)

#Then apply the data to that function
sigmaT = softfun( torch.Tensor(z) )

#Now we get results
print(sigmaT)
# Out:
# tensor([9.3908e-08, 5.1272e-06, 1.8862e-06, 1.8862e-06, 1.1293e-01, 2.7994e-04,
#         3.7885e-05, 3.4547e-08, 5.1272e-06, 2.7994e-04, 2.5527e-07, 2.5527e-07,
#         1.3937e-05, 1.3937e-05, 1.3937e-05, 1.5284e-02, 8.3448e-01, 1.5284e-02,
#         1.8862e-06, 1.0298e-04, 1.5284e-02, 2.7994e-04, 3.7885e-05, 3.7885e-05,
#         5.6227e-03])

# %%
#Show that they are the same
plt.plot(sigma,sigmaT, 'ko')
plt.xlabel('"Manual" softmax')
plt.ylabel('PyTorch nn.Softmax')
plt.title(f'The tow methods correlate at r={np.corrcoef(sigma, sigmaT)[0,1]}')
plt.show()
